# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó.

# %%
#Bai 1
a,b = map(float,input().split())
s = a*b
d = 2*(a+b)
print (f" {s} {d}")
# Out:
#  2.0 6.0

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
#Bai 2
r = float(input())
s = 3.14*(r**2)
d = 2*3.14*r
print (f"{s} {d}")
# Out:
# 3.14 6.28

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình.

# %%
#Bai 3
a,b,c = map(float,input().split())
p = (a + b + c)/2
s = p*(p-a)*(p-b)*(p-c)**(1/2)
d = 2*p
if a+b>c and b+c>a and a+c>b:
    if a==b and b==c:
        print ("Tam giac deu")
        print (f"{s} {d}")
    elif a==b or b==c or c==a:
        print ("Tam giac can")
        print (f"{s} {d}")
    elif a**2 + b**2 == c**2 or b**2 +c**2 == a**2 or a**2 + c**2 == b**2 :
        print ("Tam giac vuong")
        print (f"{s} {d}")
    else:
        print ("Tam giac thuong")
        print (f"{s} {d}")
else:
    print ("Khong la ba canh cua mot tam giac")
# Out:
# Tam giac vuong
# 36.0 12.0

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
#Bai 4
a,b = map(float,input().split())
if a!=0 and b!=0:
    x = -b/a
    print (x)
elif a==0 and b!=0:
    print ("phuong trinh vo nghiem")
elif a==0 and b==0:
    print ("phuong trinh co vo so nghiem")
# Out:
# -3.0

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
#Bai 5
a,b,c = map(float,input().split())
d = b**2 -4*a*c
if d<0:
    print ("phuong trinh vo nghiem")
elif d ==0:
    print (f"phuong trinh co nghiem kep x = {-b/(2*a)} ")
else:
    print (f"phuong trinh co hai nghiem phan biet x1 = {(-b+d**2)/(2*a)} , x2 = {(-b-d**2)/(2*a)}")
# Out:
# phuong trinh vo nghiem

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
#Trong Codinguet

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax  by  m
# cx  dy  n

# %%
a,b,p,c,d,s = map(float,input().split())
if a/b == c/d and p!=s:
    print ("He phuong trinh vo nghiem")
elif a/b == c/d and p==s:
    print ("He phuong trinh vo so nghiem")
elif a==0 and b==0 and p!=0:
    print ("He phuong trinh vo nghiem")
elif c==0 and d==0 and s!=0:
    print ("He phuong trinh vo nghiem")
elif c==0 and d==0 and s==0:
    print ("He phuong trinh vo so nghiem")
elif a==0 and b==0 and p==0:
    print ("He phuong trinh vo so nghiem")
else:
    y = -(c*p-a*s)/(a*d-c*b)
    x = (p -b*y)/a
    print (f"x={x} , y={y}")
# Out:
# x=3.5 , y=1.5
