# %% [markdown]
# W5A1
# Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( a, b) ->

# %%
#W5A1
def max_of_two(a,b):
    if a>b:
        return a
    else:
        return b
assert max_of_two(12,3) ==12
assert max_of_two(0,15) ==15
assert max_of_two(-12,56) ==56
assert max_of_two(0,-2) ==0
assert max_of_two(1,1) ==1
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A2 Viết hàm hoán đổi hai số nguyên. def swap(a, b) -> Tuple[int, int]:

# %%
#W5A2
def _swap(a,b):
    return b,a
assert _swap(1,2)==(2,1)
assert _swap(-1,-2)==(-2,-1)
assert _swap(0,3)==(3,0)
assert _swap(-12,6)==(6,-12)
assert _swap(-2,-2)==(-2,-2)
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A3 Viết hàm kiểm tra một số có phải là số nguyên tố hay không?

# %%
#W5A3
def check(n: int):
    if n<2:
        return False
    for i in range (2,int(n**0.5)+1):
        if n%i==0:
            return False
    else:
        return True
assert check(13)==True
assert check(12)==False
assert check(0)==False
assert check(-6)==False
assert check(7)==True
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A4 VIết hàm kiểm tra một số có phải số hoàn hảo hay không, xử lý trên dữ liệu kiểu số nguyên.

# %%
#W5A4
def check(n):
    sum = 0
    for i in range (1,n):
        if n%i==0:
            sum +=i
    if sum == n:
        return True
    else:
        return False
assert check(5)==False
assert check(6)==True
assert check(7)==False
assert check(8)==False
assert check(9)==False
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A5
# Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của phần tử
# đầu tiên có giá trị k trong list số nguyên,

# %%
#W5A5
def check(m: list,k: int):
   if str(k) in m:
      return m.index(str(k)) +1
   else:
      return -1
print (check("123455676",2))
# Out:
# 2

# %% [markdown]
# W5A6 Viết hàm tính giai thừa. Nhập vào số nguyên n, trả về giai thừa của n (n!)

# %%
#W5A6
def gt(n):
    gh = 1
    for i in range(1,n+1):
        gh *=i
    return gh
assert gt(1)==1
assert gt(3)==6
assert gt(2)==2
assert gt(4)==24
assert gt(5)==120
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A7
# Viết hàm giả lập một máy tính bỏ túi.
# Hàm thực hiện tính toán kết quả của phép toán giữa số \( num1 \) và \( num2 \) với toán tử \( operat
# \)
# Biết các toán tử đơn giản thực hiện phép toán lần lượt là:
# Phép trừ \( - \)
# Phép cộng \( + \)
# Phép chia \( / \)
# Phép nhân \( * \)
# Kết quả làm tròn đến chữ số thập phân thứ hai.
# Đầu vào: Hai số thực và phép toán cần thực hiện (trong số các phép toán \(+, -, *, /\)).
# Đầu ra: Kết quả phép toán.

# %%
#W5A7
def caculate(a: int,b: int,op: str):
    if op == "+":
        return a+b
    elif op =="-":
        return a-b
    elif op =="*":
        return a*b
    elif op=="/":
        return a/b
a = int(a)
b = int(b)
assert caculate(1,2,"+")==3
assert caculate(2,2,"/")==1
assert caculate(0,2,"*")==0
assert caculate(4,2,"-")==2
assert caculate(1,5,"+")==6
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A8
# Khoảng cách Hamming giữa hai số nguyên là số lượng vị trí khác nhau giữa hai dãy bits tương ứng
# của chúng. Ví dụ: Khoảng cách Hamming giữa 1 (1) và 4 (100) là 2.
# Cho hai số nguyên x và y, hãy viết hàm trả về khoảng cách Hamming giữa hai số này.
# Khoảng cách Hamming là cái tên được đặt theo tên của Richard Hamming, người giới thiệu lý
# thuyết này trong tài liệu có tính cơ sở của ông về mã phát hiện lỗi và sửa lỗi (error-detecting and
# error-correcting codes). Nó được sử dụng trong kỹ thuật viễn thông để tính số lượng các bit trong
# một từ nhị phân (binary word) bị đổi ngược, như một hình thức để ước tính số lỗi xảy ra trong quá
# trình truyền thông, và vì thế, đôi khi, nó còn được gọi là khoảng cách tín hiệu (signal distance). Việc
# phân tích trọng số Hamming của các bit còn được sử dụng trong một số ngành, bao gồm lý thuyết
# tin học, lý thuyết mã hóa, và mật mã học. Tuy vậy, khi so sánh các dãy ký tự có chiều dài khác
# nhau, hay các dãy ký tự có xu hướng không chỉ bị thay thế không thôi, mà còn bị ảnh hưởng bởi dữ
# liệu bị lồng thêm vào, hoặc bị xóa đi, phương pháp đo lường phức tạp hơn, như khoảng cách
# Levenshtein (Levenshtein distance) là một phương pháp có tác dụng và thích hợp hơn.

# %%
#W5A8
def po(x):
    du = ""
    while x>0:
        if x%2==1:
            x = x//2
            du = "1" + du 
        elif x%2==0:
            x=x//2
            du = "0" + du 
    return du
def check(a,b):
    c = len(str(po(a)))
    d = len(str(po(b)))
    kc = 0
    while c>d:
        kc +=1
        d+=1
    while c<d:
        kc+=1
        c+=1
    return kc
assert check(1,4)==2
assert check(1,1)==0
assert check(4,1)==2
assert check(5,2)==1
assert check(3,4)==1
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A9 Viết hàm trả về tổng các chữ số của số nguyên dương n

# %%
#W5A9
def sum(n):
    s = 0
    while n>0:
        s +=n%10
        n = n//10
    return s
assert sum(123)==6
assert sum(1000)==1
assert sum(12345)==15
assert sum(345)==12
assert sum(1230)==6
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A10
# Hai từ được gọi là đẳng cấu nếu các kí tự trong một từ có thể được ánh xạ để được từ còn lại. Ánh
# xạ một kí tự nghĩa là thay đổi toàn bộ các kí tự đó trong từ bởi một kí tự khác. Thứ tự của các kí tự
# được giữ không đổi. Hai kí tự khác nhau không thể ánh xạ đến cùng một kí tự, nhưng một kí tự có
# thể ánh xạ thành chính nó. Ví dụ, từ "abca" và "zbxz" là hai từ đẳng cấu vì ta có thể ánh xạ 'a' thành
# 'z', 'b' thành 'b' và 'c' thành 'x'.
# Viết hàm trả về \(true\) nếu hai từ \(a\) và \(b\) là đẳng cấu, ngược lại \(false\). Bạn có thể giả sử hai
# từ đầu vào có cùng độ dài.

# %%
#W5A10
def check(a:list,b:list):
    for i in range (0,len(a)):
        for n in range (0,len(a)):
            if a[i]==a[n]and b[i]!=b[n]:
                return False
            elif a[i]!=a[n]and b[i]==b[n]:
                return False
    else:
        return True
assert check("abcd","abfe")==True
assert check("aaaa","bbbb")==True
assert check("abcd","abff")==False
assert check("dhed","abde")==False
assert check("a","d")==True
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A11 Viết hàm is_product_divisible_by_10(a, b) trả về True nếu tích a*b chia hết cho 10, ngược lại False.

# %%
def is_product_divisible_by_10(a:int,b:int):
    if (a*b)%10==0:
        return True
    return False
assert is_product_divisible_by_10(2,5)==True
assert is_product_divisible_by_10(2,4)==False
assert is_product_divisible_by_10(4,25)==True
assert is_product_divisible_by_10(10,3)==True
assert is_product_divisible_by_10(3,7)==False
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A12
# Viết hàm divide_with_remainder(dividend, divisor) trả về bộ (q, r) sao cho dividend = divisor*q + r và 0 <= |r| < |divisor|.

# %%
#W5A12
def divide_with_remainder(dividend, divisor):
    q = dividend//divisor
    p = dividend%divisor
    return (q,p)
assert divide_with_remainder(4,3)==(1,1)
assert divide_with_remainder(10,2)==(5,0)
assert divide_with_remainder(-2,1)==(-2,0)
assert divide_with_remainder(17,3)==(5,2)
assert divide_with_remainder(1,1)==(1,0)
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A13 Viết hàm max_of_two(a, b) trả về số lớn hơn trong hai số.

# %%
#W5A13
def max_of_two(a,b):
    if a>=b:
        return a
    if a<b:
        return b
assert max_of_two(1,2)==2
assert max_of_two(1,1)==1
assert max_of_two(112,12)==112
assert max_of_two(1,-3)==1
assert max_of_two(0,0)==0
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A14 Viết hàm compute(a, b, op) thực hiện phép tính a (+|-|*|/) b tùy theo ký tự op.

# %%
#W5A14
def compute(a: int,b: int,op: str):
    if op == "+":
        return a+b
    elif op =="-":
        return a-b
    elif op =="*":
        return a*b
    elif op=="/":
        return a/b
a = int(a)
b = int(b)
assert compute(1,2,"+")==3
assert compute(2,2,"/")==1
assert compute(0,2,"*")==0
assert compute(4,2,"-")==2
assert compute(1,9,"+")==10
print ("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A15 Viết hàm is_right_triangle(a, b, c) trả về True nếu ba số có thể là ba cạnh của tam giác vuông.

# %%
#W5A15
def is_right_triangle(a,b,c):
    if a+b>c and a+c>b and b+c>a and a!=0 and b!=0 and c!= 0:
        if a**2 +b**2==c**2 or a**2+ c**2 ==b**2 or b**2 +c**2 ==a**2:
            return True
    return False
assert is_right_triangle(1,2,3)==False
assert is_right_triangle(3,4,5)==True
assert is_right_triangle(5,12,13)==True
assert is_right_triangle(1,2,5)==False
assert is_right_triangle(0,0,0)==False
print ("all test accepted")
# Out:
# all test accepted
